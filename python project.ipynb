# %%
import matplotlib.pyplot as plt
# %matplotlib inline
y=['A','B','C']
x=[2,3,4]
plt.pie(x, labels=y , autopct="%0.1f%%" , explode=[0,0.1,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f52fb39f1c0>,
#   <matplotlib.patches.Wedge at 0x7f52fb39f0d0>,
#   <matplotlib.patches.Wedge at 0x7f52fb39fd60>],
#  [Text(0.8426488837530798, 0.70706637503822, 'A'),
#   Text(-0.9192533638399032, 0.7713450933719763, 'B'),
#   Text(0.19101308558899313, -1.083288512416601, 'C')],
#  [Text(0.4596266638653162, 0.38567256820266543, '22.2%'),
#   Text(-0.5362311289066102, 0.4499513044669861, '33.3%'),
#   Text(0.10418895577581443, -0.5908846431363277, '44.4%')])

# %%
import matplotlib.pyplot as plt
import pandas as pd
coupany=['a','b','c','d']
x=[2,6,8,9]
y=[9,5,1,6]
plt.xlabel('Coupany')
plt.ylabel('profit')
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# import matplotlib.pyplot as plt
# import pandas as pd
# x=[2,6,8,9]
# y=[9,5,1,6]
# plt.bar(x,y)

# %%
import pandas as pd

import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='l5_cAJOoBKche61DIACaQP0mAncg5EhicOm5hefQ5vAi',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.eu-de.cloud-object-storage.appdomain.cloud')

bucket = 'projectwork-donotdelete-pr-lwykkhpcrfuxdy'
object_key = 'countries_and_population.xlsx'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']

df_1 = pd.read_excel(body.read())
df_1.head(10)
# Out:
#    Rank            Country / Territory     Population   Date of estimate  \
# 0     1   People's Republic of Chinan2  1,341,300,000  December 21, 2010
# 1     2                          India  1,191,730,000  December 21, 2010
# 2     3                  United States    310,951,000  December 21, 2010
# 3     4                      Indonesia    237,556,363           May 2010
# 4     5                         Brazil    190,732,694     August 1, 2010
# 5     6                       Pakistan    171,365,000  December 21, 2010
# 6     7                        Nigeria    158,259,000               2010
# 7     8                     Bangladesh    149,715,000  December 21, 2010
# 8     9                         Russia    141,927,297    January 1, 2010
# 9    10                          Japan    127,390,000   November 1, 2010
#
#     % of World population
# 0                  0.1950
# 1                  0.1730
# 2                  0.0451
# 3                  0.0345
# 4                  0.0277
# 5                  0.0249
# 6                  0.0230
# 7                  0.0217
# 8                  0.0206
# 9                  0.0185

# %%
df=df_1.copy()
df.head(15)
# Out:
#     Rank            Country / Territory     Population   Date of estimate  \
# 0      1   People's Republic of Chinan2  1,341,300,000  December 21, 2010
# 1      2                          India  1,191,730,000  December 21, 2010
# 2      3                  United States    310,951,000  December 21, 2010
# 3      4                      Indonesia    237,556,363           May 2010
# 4      5                         Brazil    190,732,694     August 1, 2010
# 5      6                       Pakistan    171,365,000  December 21, 2010
# 6      7                        Nigeria    158,259,000               2010
# 7      8                     Bangladesh    149,715,000  December 21, 2010
# 8      9                         Russia    141,927,297    January 1, 2010
# 9     10                          Japan    127,390,000   November 1, 2010
# 10    11                         Mexico    112,322,757      June 12, 2010
# 11    12                    Philippines     94,013,200           Mid-2010
# 12    13                        Vietnam     85,846,997      April 1, 2009
# 13    14                        Germany     81,802,000  December 31, 2009
# 14    15                          Egypt     79,492,000  December 21, 2010
#
#      % of World population
# 0                   0.1950
# 1                   0.1730
# 2                   0.0451
# 3                   0.0345
# 4                   0.0277
# 5                   0.0249
# 6                   0.0230
# 7                   0.0217
# 8                   0.0206
# 9                   0.0185
# 10                  0.0163
# 11                  0.0136
# 12                  0.0125
# 13                  0.0119
# 14                  0.0115

# %%
df.shape
# Out:
# (100, 5)

# %%
df.describe()
# Out:
#              Rank   % of World population
# count  100.000000              100.000000
# mean    50.500000                0.009603
# std     29.011492                0.026157
# min      1.000000                0.001000
# 25%     25.750000                0.001600
# 50%     50.500000                0.003300
# 75%     75.250000                0.007075
# max    100.000000                0.195000

# %%
df["Date of estimate"].unique()
# Out:
# array(['December 21, 2010', 'May 2010', 'August 1, 2010', 2010,
#        'January 1, 2010', 'November 1, 2010', 'June 12, 2010', 'Mid-2010',
#        'April 1, 2009', 'December 31, 2009', 'December 1, 2009',
#        'Mid-2009', 'July 31, 2010', 'July 1, 2010', 'October 1, 2010',
#        'October 27, 2010', 'August 24-25, 2009', 'June 30, 2010', 2011,
#        'July 2010', 'October 31, 2010', 2009, 'January, 1 2010',
#        'March 3, 2008', '2010 average', 'July 1, 2009'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    100 non-null    int64
#  1   Country / Territory     100 non-null    object
#  2   Population              100 non-null    object
#  3   Date of estimate        100 non-null    object
#  4    % of World population  100 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 4.0+ KB

# %%
df.isnull()
# Out:
#      Rank  Country / Territory  Population  Date of estimate  \
# 0   False                False       False             False
# 1   False                False       False             False
# 2   False                False       False             False
# 3   False                False       False             False
# 4   False                False       False             False
# ..    ...                  ...         ...               ...
# 95  False                False       False             False
# 96  False                False       False             False
# 97  False                False       False             False
# 98  False                False       False             False
# 99  False                False       False             False
#
#      % of World population
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ..                     ...
# 95                   False
# 96                   False
# 97                   False
# 98                   False
# 99                   False
#
# [100 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Rank                      0
# Country / Territory       0
# Population                0
# Date of estimate          0
#  % of World population    0
# dtype: int64

# %%
df.head(50)
# Out:
#     Rank             Country / Territory     Population    Date of estimate  \
# 0      1    People's Republic of Chinan2  1,341,300,000   December 21, 2010
# 1      2                           India  1,191,730,000   December 21, 2010
# 2      3                   United States    310,951,000   December 21, 2010
# 3      4                       Indonesia    237,556,363            May 2010
# 4      5                          Brazil    190,732,694      August 1, 2010
# 5      6                        Pakistan    171,365,000   December 21, 2010
# 6      7                         Nigeria    158,259,000                2010
# 7      8                      Bangladesh    149,715,000   December 21, 2010
# 8      9                          Russia    141,927,297     January 1, 2010
# 9     10                           Japan    127,390,000    November 1, 2010
# 10    11                          Mexico    112,322,757       June 12, 2010
# 11    12                     Philippines     94,013,200            Mid-2010
# 12    13                         Vietnam     85,846,997       April 1, 2009
# 13    14                         Germany     81,802,000   December 31, 2009
# 14    15                           Egypt     79,492,000   December 21, 2010
# 15    16                        Ethiopia     79,455,634                2010
# 16    17                            Iran     75,078,000                2010
# 17    18                          Turkey     72,561,312   December 31, 2009
# 18    19              Dem. Rep. of Congo     67,827,000                2010
# 19    20                        Thailand     67,070,000    December 1, 2009
# 20    21                        Francen3     65,447,374     January 1, 2010
# 21    22                  United Kingdom     61,792,000            Mid-2009
# 22    23                           Italy     60,494,632       July 31, 2010
# 23    24                 Myanmar (Burma)     50,496,000                2010
# 24    25                    South Africa     49,991,300        July 1, 2010
# 25    26                     South Korea     48,501,000                2010
# 26    27                           Spain     46,122,169     October 1, 2010
# 27    28                         Ukraine     45,822,214     October 1, 2010
# 28    29                        Colombia     45,767,000   December 21, 2010
# 29    30                           Sudan     43,192,000                2010
# 30    31                        Tanzania     43,187,823                2010
# 31    32                       Argentina     40,091,359    October 27, 2010
# 32    33                           Kenya     38,610,097  August 24-25, 2009
# 33    34                          Poland     38,092,000                2010
# 34    35                         Algeria     35,600,000     January 1, 2010
# 35    36                          Canada     34,295,000   December 21, 2010
# 36    37                         Morocco     32,011,000   December 21, 2010
# 37    38                          Uganda     31,800,000                2010
# 38    39                            Iraq     31,467,000                2010
# 39    40                            Peru     29,461,933       June 30, 2010
# 40    41                     Afghanistan     29,117,000                2010
# 41    42                       Venezuela     29,042,000   December 21, 2010
# 42    43                           Nepal     28,584,975                2011
# 43    44                        Malaysia     28,250,500           July 2010
# 44    45                      Uzbekistan     27,794,000                2010
# 45    46                    Saudi Arabia     27,136,977                2010
# 46    47                     North Korea     23,991,000                2010
# 47    48                           Ghana     23,951,519        July 1, 2010
# 48    49   Republic of China (Taiwan) n4     23,150,923    October 31, 2010
# 49    50                     Australian5     22,565,000   December 21, 2010
#
#      % of World population
# 0                   0.1950
# 1                   0.1730
# 2                   0.0451
# 3                   0.0345
# 4                   0.0277
# 5                   0.0249
# 6                   0.0230
# 7                   0.0217
# 8                   0.0206
# 9                   0.0185
# 10                  0.0163
# 11                  0.0136
# 12                  0.0125
# 13                  0.0119
# 14                  0.0115
# 15                  0.0115
# 16                  0.0109
# 17                  0.0105
# 18                  0.0098
# 19                  0.0097
# 20                  0.0095
# 21                  0.0090
# 22                  0.0088
# 23                  0.0073
# 24                  0.0073
# 25                  0.0070
# 26                  0.0067
# 27                  0.0067
# 28                  0.0066
# 29                  0.0063
# 30                  0.0063
# 31                  0.0058
# 32                  0.0056
# 33                  0.0055
# 34                  0.0052
# 35                  0.0050
# 36                  0.0046
# 37                  0.0046
# 38                  0.0046
# 39                  0.0043
# 40                  0.0042
# 41                  0.0042
# 42                  0.0041
# 43                  0.0041
# 44                  0.0040
# 45                  0.0039
# 46                  0.0035
# 47                  0.0035
# 48                  0.0034
# 49                  0.0033

# %%
import matplotlib.pyplot as plt

A=['Ayush','Utsav','Ansh']
X=[3,6,8]
plt.pie(X , labels=A , autopct = '%0.1f%%', explode=[0,0,0.1] )
# Out:
# ([<matplotlib.patches.Wedge at 0x7f4c2b39e9e0>,
#   <matplotlib.patches.Wedge at 0x7f4c2b39e8f0>,
#   <matplotlib.patches.Wedge at 0x7f4c2b39f550>],
#  [Text(0.9352388413294948, 0.5790753920420592, 'Ayush'),
#   Text(-0.6628981483626761, 0.8778189134994391, 'Utsav'),
#   Text(0.11072213664804118, -1.1948810017972888, 'Ansh')],
#  [Text(0.5101302770888152, 0.315859304750214, '17.6%'),
#   Text(-0.36158080819782334, 0.47881031645423944, '35.3%'),
#   Text(0.06458791304469069, -0.697013917715085, '47.1%')])

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='l5_cAJOoBKche61DIACaQP0mAncg5EhicOm5hefQ5vAi',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.eu-de.cloud-object-storage.appdomain.cloud')

bucket = 'projectwork-donotdelete-pr-lwykkhpcrfuxdy'
object_key = 'countries_and_population.xlsx'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']

df_2 = pd.read_excel(body.read())
df_2.head(10)
# Out:
#    Rank            Country / Territory     Population   Date of estimate  \
# 0     1   People's Republic of Chinan2  1,341,300,000  December 21, 2010
# 1     2                          India  1,191,730,000  December 21, 2010
# 2     3                  United States    310,951,000  December 21, 2010
# 3     4                      Indonesia    237,556,363           May 2010
# 4     5                         Brazil    190,732,694     August 1, 2010
# 5     6                       Pakistan    171,365,000  December 21, 2010
# 6     7                        Nigeria    158,259,000               2010
# 7     8                     Bangladesh    149,715,000  December 21, 2010
# 8     9                         Russia    141,927,297    January 1, 2010
# 9    10                          Japan    127,390,000   November 1, 2010
#
#     % of World population
# 0                  0.1950
# 1                  0.1730
# 2                  0.0451
# 3                  0.0345
# 4                  0.0277
# 5                  0.0249
# 6                  0.0230
# 7                  0.0217
# 8                  0.0206
# 9                  0.0185

# %%
df=df_2.copy()
df.head(50)
# Out:
#     Rank             Country / Territory     Population    Date of estimate  \
# 0      1    People's Republic of Chinan2  1,341,300,000   December 21, 2010
# 1      2                           India  1,191,730,000   December 21, 2010
# 2      3                   United States    310,951,000   December 21, 2010
# 3      4                       Indonesia    237,556,363            May 2010
# 4      5                          Brazil    190,732,694      August 1, 2010
# 5      6                        Pakistan    171,365,000   December 21, 2010
# 6      7                         Nigeria    158,259,000                2010
# 7      8                      Bangladesh    149,715,000   December 21, 2010
# 8      9                          Russia    141,927,297     January 1, 2010
# 9     10                           Japan    127,390,000    November 1, 2010
# 10    11                          Mexico    112,322,757       June 12, 2010
# 11    12                     Philippines     94,013,200            Mid-2010
# 12    13                         Vietnam     85,846,997       April 1, 2009
# 13    14                         Germany     81,802,000   December 31, 2009
# 14    15                           Egypt     79,492,000   December 21, 2010
# 15    16                        Ethiopia     79,455,634                2010
# 16    17                            Iran     75,078,000                2010
# 17    18                          Turkey     72,561,312   December 31, 2009
# 18    19              Dem. Rep. of Congo     67,827,000                2010
# 19    20                        Thailand     67,070,000    December 1, 2009
# 20    21                        Francen3     65,447,374     January 1, 2010
# 21    22                  United Kingdom     61,792,000            Mid-2009
# 22    23                           Italy     60,494,632       July 31, 2010
# 23    24                 Myanmar (Burma)     50,496,000                2010
# 24    25                    South Africa     49,991,300        July 1, 2010
# 25    26                     South Korea     48,501,000                2010
# 26    27                           Spain     46,122,169     October 1, 2010
# 27    28                         Ukraine     45,822,214     October 1, 2010
# 28    29                        Colombia     45,767,000   December 21, 2010
# 29    30                           Sudan     43,192,000                2010
# 30    31                        Tanzania     43,187,823                2010
# 31    32                       Argentina     40,091,359    October 27, 2010
# 32    33                           Kenya     38,610,097  August 24-25, 2009
# 33    34                          Poland     38,092,000                2010
# 34    35                         Algeria     35,600,000     January 1, 2010
# 35    36                          Canada     34,295,000   December 21, 2010
# 36    37                         Morocco     32,011,000   December 21, 2010
# 37    38                          Uganda     31,800,000                2010
# 38    39                            Iraq     31,467,000                2010
# 39    40                            Peru     29,461,933       June 30, 2010
# 40    41                     Afghanistan     29,117,000                2010
# 41    42                       Venezuela     29,042,000   December 21, 2010
# 42    43                           Nepal     28,584,975                2011
# 43    44                        Malaysia     28,250,500           July 2010
# 44    45                      Uzbekistan     27,794,000                2010
# 45    46                    Saudi Arabia     27,136,977                2010
# 46    47                     North Korea     23,991,000                2010
# 47    48                           Ghana     23,951,519        July 1, 2010
# 48    49   Republic of China (Taiwan) n4     23,150,923    October 31, 2010
# 49    50                     Australian5     22,565,000   December 21, 2010
#
#      % of World population
# 0                   0.1950
# 1                   0.1730
# 2                   0.0451
# 3                   0.0345
# 4                   0.0277
# 5                   0.0249
# 6                   0.0230
# 7                   0.0217
# 8                   0.0206
# 9                   0.0185
# 10                  0.0163
# 11                  0.0136
# 12                  0.0125
# 13                  0.0119
# 14                  0.0115
# 15                  0.0115
# 16                  0.0109
# 17                  0.0105
# 18                  0.0098
# 19                  0.0097
# 20                  0.0095
# 21                  0.0090
# 22                  0.0088
# 23                  0.0073
# 24                  0.0073
# 25                  0.0070
# 26                  0.0067
# 27                  0.0067
# 28                  0.0066
# 29                  0.0063
# 30                  0.0063
# 31                  0.0058
# 32                  0.0056
# 33                  0.0055
# 34                  0.0052
# 35                  0.0050
# 36                  0.0046
# 37                  0.0046
# 38                  0.0046
# 39                  0.0043
# 40                  0.0042
# 41                  0.0042
# 42                  0.0041
# 43                  0.0041
# 44                  0.0040
# 45                  0.0039
# 46                  0.0035
# 47                  0.0035
# 48                  0.0034
# 49                  0.0033

# %%
df.info
# Out:
# <bound method DataFrame.info of     Rank            Country / Territory     Population   Date of estimate  \
# 0      1   People's Republic of Chinan2  1,341,300,000  December 21, 2010
# 1      2                          India  1,191,730,000  December 21, 2010
# 2      3                  United States    310,951,000  December 21, 2010
# 3      4                      Indonesia    237,556,363           May 2010
# 4      5                         Brazil    190,732,694     August 1, 2010
# ..   ...                            ...            ...                ...
# 95    96                       Honduras      7,616,000               2010
# 96    97                       Bulgaria      7,528,103               2010
# 97    98                     Tajikistan      7,075,000               2010
# 98    99                      Hong Kong      7,061,200      July 31, 2010
# 99   100               Papua New Guinea      6,888,000               2010
#
#      % of World population
# 0                  0.19500
# 1                  0.17300
# 2                  0.04510
# 3                  0.03450
# 4                  0.02770
# ..                     ...
# 95                 0.00110
# 96                 0.00110
# 97                 0.00103
# 98                 0.00102
# 99                 0.00100
#
# [100 rows x 5 columns]>
